# %%
import numpy as np

# %%
# Built-in Matemetical Functions

arr = np.array([3,3,25,2])
arr
# Out:
# array([ 3,  3, 25,  2])

# %%
np.mean(arr)
# Out:
# np.float64(8.25)

# %%
np.std(arr)
# Out:
# np.float64(9.67923034130297)

# %%
np.var(arr)
# Out:
# np.float64(93.6875)

# %%
np.min(arr)
# Out:
# np.int64(2)

# %%
np.sum(arr)
# Out:
# np.int64(33)

# %%
np.prod(arr)
# Out:
# np.int64(450)

# %%
np.median(arr)
# Out:
# np.float64(3.0)

# %%
np.percentile(arr, 50)
# Out:
# np.float64(3.0)

# %%
np.argmin(arr)
# Out:
# np.int64(3)

# %%
np.argmax(arr)
# Out:
# np.int64(2)

# %%
np.unique(arr)
# Out:
# array([ 2,  3, 25])

# %%
np.diff(arr)
# Out:
# array([  0,  22, -23])

# %%
np.cumsum(arr)
# Out:
# array([ 3,  6, 31, 33])

# %%
np.linspace(0, 10, 5)  # 5 numbers from 0 to 10
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)
# Out:
# array([1.09861229, 1.09861229, 3.21887582, 0.69314718])

# %%
np.exp(arr)
# Out:
# array([2.00855369e+01, 2.00855369e+01, 7.20048993e+10, 7.38905610e+00])
